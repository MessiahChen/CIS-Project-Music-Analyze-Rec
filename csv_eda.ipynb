# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# track.csv contains the origination information for each track(artist, album year of release, genre catagories,etc)
# genres.csv is a genre-look up table,
# features.csv and echonest.csv are two sets of extracted audio features generated through the Librosa,
# and Echonest libraries, with each song labeled by it's track id.

# %%
tracks = pd.read_csv('tracks.csv')
genres = pd.read_csv('genres.csv')
features = pd.read_csv('features.csv')
echonest = pd.read_csv('echonest.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-65b17727971c> in <module>
# ----> 1 tracks = pd.read_csv('tracks.csv')
#       2 genres = pd.read_csv('genres.csv')
#       3 features = pd.read_csv('features.csv')
#       4 echonest = pd.read_csv('echonest.csv')
#
# ...

# %%
#tracks
tracks.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-539371acc817> in <module>
#       1 #tracks
# ----> 2 tracks.columns
#
# NameError: name 'tracks' is not defined

# %%
tracks.head()
# Out:
#   Unnamed: 0     album              album.1              album.2   album.3  \
# 0        NaN  comments         date_created        date_released  engineer
# 1   track_id       NaN                  NaN                  NaN       NaN
# 2          2         0  2008-11-26 01:44:45  2009-01-05 00:00:00       NaN
# 3          3         0  2008-11-26 01:44:45  2009-01-05 00:00:00       NaN
# 4          5         0  2008-11-26 01:44:45  2009-01-05 00:00:00       NaN
#
#      album.4 album.5      album.6  album.7   album.8      ...       \
# 0  favorites      id  information  listens  producer      ...
# 1        NaN     NaN          NaN      NaN       NaN      ...
# 2          4       1      <p></p>     6073       NaN      ...
# 3          4       1      <p></p>     6073       NaN      ...
# 4          4       1      <p></p>     6073       NaN      ...
#
#       track.10  track.11       track.12  \
# 0  information  interest  language_code
# 1          NaN       NaN            NaN
# ...

# %%
tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106576 entries, 0 to 106575
# Data columns (total 53 columns):
# Unnamed: 0    106575 non-null object
# album         106575 non-null object
# album.1       103046 non-null object
# album.2       70295 non-null object
# album.3       15297 non-null object
# album.4       106575 non-null object
# album.5       106575 non-null object
# album.6       83150 non-null object
# album.7       106575 non-null object
# album.8       18061 non-null object
# album.9       106575 non-null object
# album.10      105550 non-null object
# album.11      106575 non-null object
# album.12      100067 non-null object
# artist        22712 non-null object
# artist.1      5376 non-null object
# artist.2      14272 non-null object
# artist.3      71157 non-null object
# artist.4      106575 non-null object
# artist.5      105719 non-null object
# artist.6      106575 non-null object
# artist.7      106575 non-null object
# ...

# %%
tracks.describe(include='all')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0048453cc73e> in <module>
# ----> 1 tracks.describe(include='all')
#
# NameError: name 'tracks' is not defined

# %%
#genres
genres.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-981e8d413439> in <module>
#       1 #genres
# ----> 2 genres.columns
#
# NameError: name 'genres' is not defined

# %%
genres.head()
# Out:
#    genre_id  #tracks  parent          title  top_level
# 0         1     8693      38    Avant-Garde         38
# 1         2     5271       0  International          2
# 2         3     1752       0          Blues          3
# 3         4     4126       0           Jazz          4
# 4         5     4106       0      Classical          5

# %%
genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163 entries, 0 to 162
# Data columns (total 5 columns):
# genre_id     163 non-null int64
# #tracks      163 non-null int64
# parent       163 non-null int64
# title        163 non-null object
# top_level    163 non-null int64
# dtypes: int64(4), object(1)
# memory usage: 6.4+ KB

# %%
genres.isnull().sum()
# Out:
# genre_id     0
# #tracks      0
# parent       0
# title        0
# top_level    0
# dtype: int64

# %%
genres.describe(include='all')
# Out:
#            genre_id       #tracks       parent      title    top_level
# count    163.000000    163.000000   163.000000        163   163.000000
# unique          NaN           NaN          NaN        163          NaN
# top             NaN           NaN          NaN  Loud-Rock          NaN
# freq            NaN           NaN          NaN          1          NaN
# mean     254.116564   2142.085890    60.447853        NaN    51.374233
# std      265.048642   5199.542574   185.396011        NaN   211.470836
# min        1.000000      0.000000     0.000000        NaN     2.000000
# 25%       60.500000    125.000000     5.000000        NaN     5.000000
# 50%      172.000000    563.000000    15.000000        NaN    12.000000
# 75%      400.500000   1846.500000    38.000000        NaN    20.000000
# max     1235.000000  38154.000000  1235.000000        NaN  1235.000000

# %%
#features
features.columns
# Out:
# Index(['feature', 'chroma_cens', 'chroma_cens.1', 'chroma_cens.2',
#        'chroma_cens.3', 'chroma_cens.4', 'chroma_cens.5', 'chroma_cens.6',
#        'chroma_cens.7', 'chroma_cens.8',
#        ...
#        'tonnetz.39', 'tonnetz.40', 'tonnetz.41', 'zcr', 'zcr.1', 'zcr.2',
#        'zcr.3', 'zcr.4', 'zcr.5', 'zcr.6'],
#       dtype='object', length=519)

# %%
features.head(8)
# Out:
#       feature        chroma_cens      chroma_cens.1      chroma_cens.2  \
# 0  statistics           kurtosis           kurtosis           kurtosis
# 1      number                 01                 02                 03
# 2    track_id                NaN                NaN                NaN
# 3           2   7.1806526184e+00   5.2303090096e+00   2.4932080507e-01
# 4           3   1.8889633417e+00   7.6053929329e-01   3.4529656172e-01
# 5           5   5.2756297588e-01  -7.7654317021e-02  -2.7961030602e-01
# 6          10   3.7022454739e+00  -2.9119303823e-01   2.1967420578e+00
# 7          20  -1.9383698702e-01  -1.9852678478e-01   2.0154602826e-01
#
#        chroma_cens.3     chroma_cens.4     chroma_cens.5      chroma_cens.6  \
# 0           kurtosis          kurtosis          kurtosis           kurtosis
# 1                 04                05                06                 07
# 2                NaN               NaN               NaN                NaN
# ...

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106577 entries, 0 to 106576
# Columns: 519 entries, feature to zcr.6
# dtypes: object(519)
# memory usage: 422.0+ MB

# %%
features.describe(include='all')
# Out:
#         feature    chroma_cens  chroma_cens.1  chroma_cens.2  chroma_cens.3  \
# count    106577  106576.000000    106576.0000  106576.000000  106576.000000
# unique   106577  104376.000000    104381.0000  104389.000000  104394.000000
# top      114901       2.120035        -0.1481       0.687363       1.388522
# freq          1      90.000000        90.0000      90.000000      90.000000
#
#         chroma_cens.4  chroma_cens.5  chroma_cens.6  chroma_cens.7  \
# count   106576.000000  106576.000000  106576.000000  106576.000000
# unique  104409.000000  104378.000000  104389.000000  104383.000000
# top         -0.779828      -1.049356      -1.352663      -1.146229
# freq        90.000000      90.000000      90.000000      90.000000
#
#         chroma_cens.8      ...           tonnetz.39     tonnetz.40  \
# count    106576.00000      ...        106576.000000  106576.000000
# unique   104374.00000      ...        104170.000000  103962.000000
# ...

# %%
#echonest
echonest.columns
# Out:
# Index(['Unnamed: 0', 'echonest', 'echonest.1', 'echonest.2', 'echonest.3',
#        'echonest.4', 'echonest.5', 'echonest.6', 'echonest.7', 'echonest.8',
#        ...
#        'echonest.239', 'echonest.240', 'echonest.241', 'echonest.242',
#        'echonest.243', 'echonest.244', 'echonest.245', 'echonest.246',
#        'echonest.247', 'echonest.248'],
#       dtype='object', length=250)

# %%
echonest.head(8)
# Out:
#   Unnamed: 0        echonest      echonest.1      echonest.2  \
# 0        NaN  audio_features  audio_features  audio_features
# 1        NaN    acousticness    danceability          energy
# 2   track_id             NaN             NaN             NaN
# 3          2    0.4166752327    0.6758939853    0.6344762684
# 4          3    0.3744077685    0.5286430621    0.8174611317
# 5          5    0.0435668989    0.7455658702    0.7014699916
# 6         10    0.9516699648    0.6581786543    0.9245251615
# 7        134    0.4522173071    0.5132380502    0.5604099311
#
#          echonest.3      echonest.4      echonest.5      echonest.6  \
# 0    audio_features  audio_features  audio_features  audio_features
# 1  instrumentalness        liveness     speechiness           tempo
# 2               NaN             NaN             NaN             NaN
# 3      0.0106280683    0.1776465712    0.1593100648  165.9220000000
# 4      0.0018511032    0.1058799438    0.4618181276  126.9570000000
# ...

# %%
echonest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13132 entries, 0 to 13131
# Columns: 250 entries, Unnamed: 0 to echonest.248
# dtypes: object(250)
# memory usage: 25.0+ MB

# %%
echonest.describe(include='all')
# Out:
#         Unnamed: 0      echonest    echonest.1    echonest.2   echonest.3  \
# count        13130  13131.000000         13131         13131  13131.00000
# unique       13130  12912.000000         13131         13131  12990.00000
# top          32760      0.995796  0.5429413172  0.3249142017      0.97287
# freq             1    195.000000             1             1     38.00000
#
#           echonest.4    echonest.5  echonest.6   echonest.7 echonest.8  \
# count          13131         13131    13131.00  13131.00000       2719
# unique         13131         13131    12314.00  13129.00000        444
# top     0.1087110744  0.5752967282      100.01      0.99999       2008
# freq               1             1        6.00      3.00000         89
#
#             ...       echonest.239   echonest.240  echonest.241  echonest.242  \
# count       ...       13131.000000          13131  13131.000000    13131.0000
# unique      ...       13130.000000          13130  13126.000000     8929.0000
# ...
